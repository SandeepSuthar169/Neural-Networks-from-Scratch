# %% [markdown]
#  y=2x

# %%
def f(x):
  return 2*x
f(3)
# Out:
# 6

# %% [markdown]
# linear function

# %%
import matplotlib.pyplot as plt
import numpy as np

def f(x):
  return 2*x

x=np.array(range(5))
y=f(x)

print(x)
print(y)

plt.plot(x,y)
plt.show()
# Out:
# [0 1 2 3 4]
# [0 2 4 6 8]

# %%
print((y[1] - y[0]) / (x[1] - x[0]))
# Out:
# 2.0

# %% [markdown]
# Non linear function

# %%
def f(x):
  return 2*x**2

y=f(x)
print(x)
print(y)
# Out:
# [0 1 2 3 4]
# [ 0  2  8 18 32]

# %%
print((y[1] - y[0]) / (x[1] - x[0]))
# Out:
# 2.0

# %%
print((y[3] -y[2]) / (x[3] - x[2]))
# Out:
# 10.0

# %%
import matplotlib.pyplot as plt
import numpy as np
r=0.1
def f(x):
  return 2*x**2

x=np.arange(-6,6,0.00001)
y=f(x)

print(x)
print(y)

plt.plot(x,y)
plt.show()
# Out:
# [-6.      -5.99999 -5.99998 ...  5.99997  5.99998  5.99999]
# [72.         71.99976    71.99952    ... 71.99927999 71.99951999
#  71.99975999]

# %%
import matplotlib.pyplot as plt
import numpy as np
r=0.1
def f(x):
  return 2*x**2

x=np.arange(0,6,0.001)
y=f(x)

print(x)
print(y)

plt.plot(x,y)


delta = 0.001
x1 = 2
x2 = x1+delta
y1 = f(x1)
y2 = f(x2)

print((x1, y1), (x2, y2))
approximate_derivative  = (y2-y1) / (x2- x1)
b=y2 - approximate_derivative*x2
print(b)
print(approximate_derivative)

def line(x):
  return approximate_derivative*x+b

line_plot=[x1-0.9,x1, x1+0.9]
plt.plot(line_plot,[line(i) for i in line_plot])
plt.show()
# Out:
# [0.000e+00 1.000e-03 2.000e-03 ... 5.997e+00 5.998e+00 5.999e+00]
# [0.0000000e+00 2.0000000e-06 8.0000000e-06 ... 7.1928018e+01 7.1952008e+01
#  7.1976002e+01]
# (2, 8) (2.001, 8.008002)
# -8.004000000000557
# 8.00200000000028

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
  return 2*x**2

x=np.array(np.arange(0,5,0.001))
y=f(x)

plt.plot(x,y)
colors=["k", "g", "r", "b", "c"]

def approxomate_tangent_line(x, approximate_derivatibe):
  return (approximate_derivative*x)+b

for i in range(5):
  delta= 0.0001
  x1= i
  x2 = x1+delta

  y1 = f(x1)
  y2= f(x2)
  print((x1, y1),(x2, y2))
  approximate_derivative = (y2-y1)/ (x2-x1)
  b= y2 - (approximate_derivative*x2)
  #print(approximate_derivative)
  #print(b)
  line_plot = [x1-0.9, x1, x1+0.9]

  plt.scatter(x1, y1, c=colors[i])
  plt.plot([point for point in line_plot],
           [approxomate_tangent_line(point, approximate_derivative )
               for point in line_plot],
           c=colors[i])
  print("Approximate derivative for f(x) ", f"x = {x1} is {approximate_derivative}")
plt.show()
# Out:
# (0, 0) (0.0001, 2e-08)
# Approximate derivative for f(x)  x = 0 is 0.00019999999999999998
# (1, 2) (1.0001, 2.00040002)
# Approximate derivative for f(x)  x = 1 is 4.0001999999987845
# (2, 8) (2.0001, 8.000800020000002)
# Approximate derivative for f(x)  x = 2 is 8.000199999998785
# (3, 18) (3.0001, 18.001200020000002)
# Approximate derivative for f(x)  x = 3 is 12.000199999998785
# (4, 32) (4.0001, 32.00160002)
# Approximate derivative for f(x)  x = 4 is 16.000200000016548
